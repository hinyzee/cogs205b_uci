# %%
import json
import urllib.request
import urllib.parse

params = urllib.parse.urlencode({
    "latitude": 33.64054,
    "longitude": -117.83891,
    "current": "apparent_temperature,precipitation_probability,relative_humidity_2m",
})
endpoint = f"https://api.open-meteo.com/v1/forecast?{params}"

with urllib.request.urlopen(endpoint) as resp:
    data = json.loads(resp.read().decode("utf-8"))

# %%
data['current']
# Out:
# {'time': '2026-05-13T20:45',
#  'interval': 900,
#  'apparent_temperature': 22.2,
#  'precipitation_probability': 0,
#  'relative_humidity_2m': 62}

# %%
# using gemini
url = (
    "https://generativelanguage.googleapis.com/v1beta/models/"
    "gemini-2.5-flash:generateContent"
)

body = {
    "contents": [
        {"parts": [{"text": "Explain diffusion models in cognitive science in one sentence."}]}
    ]
}
body_bytes = json.dumps(body).encode("utf-8")

req = urllib.request.Request(
    url,
    data=body_bytes,
    headers={
        "Content-Type": "application/json",
        "x-goog-api-key": "AIzaSyBXzYJvgqag1TVREbg12ODtUiOLNokgt4w",
    },
    method="POST"
)

with urllib.request.urlopen(req) as resp:
    response_data = json.loads(resp.read().decode("utf-8"))

text = response_data["candidates"][0]["content"]["parts"][0]["text"]
print(text)
# Out:
# In cognitive science, diffusion models explain how information gradually accumulates and refines over time, enabling processes like decision-making, perception, or the generation of internal representations from noisy input.

# %%
# wrap text when printing
import textwrap
wrapper = textwrap.TextWrapper(width=80)
print(wrapper.fill(text))
# Out:
# In cognitive science, diffusion models explain how information gradually
# accumulates and refines over time, enabling processes like decision-making,
# perception, or the generation of internal representations from noisy input.
